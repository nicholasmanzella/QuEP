# %%
import h5py
# %matplotlib notebook
import numpy as np
import sys, os

sys.path.append('path/to/pyVisOS')

import osh5io
import osh5def
import osh5vis
import osh5utils
import matplotlib.pyplot as plt

# %%
f=h5py.File('MS/FLD/e1/e1-000015.h5','r')

# %%
list(f.attrs)
# Out:
# ['ITER', 'LABEL', 'NAME', 'TIME', 'TIME UNITS', 'TYPE', 'UNITS']

# %%
f.attrs['ITER']
# Out:
# array([15], dtype=int32)

# %%
f['AXIS/AXIS1'][:]
# Out:
# array([0.  , 6.58])

# %%
list(f['AXIS/AXIS1'].attrs)
# Out:
# ['LONG_NAME', 'NAME', 'TYPE', 'UNITS']

# %%
f['AXIS/AXIS1'].attrs['UNITS'][0]
# Out:
# b'c / \\omega_p'

# %%
list(f['SIMULATION'].attrs)
# Out:
# ['COMPILE_TIME',
#  'DT',
#  'GIT_VERSION',
#  'INPUT_FILE',
#  'INPUT_FILE_CRC32',
#  'MOVE C',
#  'NDIMS',
#  'NX',
#  'PAR_NODE_CONF',
#  'PAR_NX_X1',
#  'PAR_NX_X2',
#  'PAR_NX_X3',
#  'PERIODIC',
#  'TIMESTAMP',
#  'XMAX',
#  'XMIN']

# %%
f['e1'][0,0,:]
# Out:
# array([-1.9261192e-06,  4.2452859e-07, -1.0361176e-06,  3.7047687e-07,
#        -6.7279728e-08,  1.0360949e-07,  6.8081434e-09,  3.3478916e-08,
#        -1.3123947e-08, -7.2304346e-10, -6.0741784e-10, -5.1669048e-11,
#        -2.4067640e-13, -5.7974852e-14,  0.0000000e+00,  0.0000000e+00,
#         0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#         0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#         0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#         0.0000000e+00,  0.0000000e+00], dtype=float32)

# %%
c = osh5io.read_h5('MS/FLD/e1/e1-000015.h5')
plt.figure()
osh5vis.osplot(c[0,:,:])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
c
# Out:
# osh5def.H5Data at 0x7ff5e074b3d0, shape(9, 9, 30),
# axis:
#   osh5def.DataAxis at 0x7ff60136f550: size=9, (min, max)=(-0.942, 0.9420000000000004), {'UNITS': osh5def.OSUnits at 0x7ff60136f750: ['m_e', 'c', '\\omega_p', 'e', 'n_0']=[0, 1, -1, 0, 0], 'LONG_NAME': 'x_2', 'NAME': 'x2', 'TYPE': 'linear'}
#   osh5def.DataAxis at 0x7ff60136f690: size=30, (min, max)=(0.0, 6.579999999999999), {'UNITS': osh5def.OSUnits at 0x7ff60136f850: ['m_e', 'c', '\\omega_p', 'e', 'n_0']=[0, 1, -1, 0, 0], 'LONG_NAME': 'x_1', 'NAME': 'x1', 'TYPE': 'linear'}
# data_attrs: {'UNITS': osh5def.OSUnits at 0x7ff60136f450: ['m_e', 'c', '\\omega_p', 'e', 'n_0']=[0, 0, 0, 0, 0], 'NAME': 'e1'}
# run_attrs:{'ITER': array([15], dtype=int32), 'LABEL': 'E_1', 'NAME': 'e1', 'TIME': array([1.83]), 'TIME UNITS': '1 / \\omega_p', 'TYPE': 'grid', 'UNITS': 'm_e c \\omega_p e^{-1}'}

# %%
# 2d data
# x1 = longitudinal direction, laser propagates in this direction
# x2 = transverse direction
# x3 = assumed to be infinite

# %%
# Quasi-3d
# x1 = 'z'
# x2 = 'x', theta = 0, laser polarized in this direction
# x3 = 'y', theta = pi/2

# Grid data has 2 dimensions
# x1 = longitudinal (z)
# x2 = r

# Field data has 3 dimensions
# e1 = longitudinal direction
# 

# E_tot = E_0_re + E_1_re * cos(theta) + E_1_im * sin(theta)
