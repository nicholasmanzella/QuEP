# %%
import numpy as np
import matplotlib.colors as col
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.ticker as ticker
import pdb
import time
import progressbar
import include.simulations.useQuasi3D as sim

import h5py

# %% [markdown]
# # Testing reading the h5 file

# %%
Quasi_ID = '000067'
filename = r'data/OSIRIS/Quasi3D/charge_cyl_m-ions-0-re-'+ Quasi_ID + '.h5'

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[0]

    # Get the data
    data = list(f[a_group_key])
    fields = f['AXIS']['AXIS1']
    r_fields = f['AXIS']['AXIS2']
    print(fields[:])
    print(r_fields[:])
# Out:
# Keys: <KeysViewHDF5 ['AXIS', 'SIMULATION', 'charge_cyl_m']>
# [-0.20200261 39.79799739]
# [-5.21662246e-03  1.17947834e+01]

# %%
# Load data from npz file export from main.py
fname = '000032_testing.npz'
data = np.load('./data/' + fname) # Change this line as needed
x_0 = data['x_init']
y_0 = data['y_init']
xi_0 = data['xi_init']
z_0 = data['z_init']
x_f = data['x_dat']
y_f = data['y_dat']
xi_f = data['xi_dat']
z_f = data['z_dat']
px_f = data['px_dat']
py_f = data['py_dat']
pz_f = data['pz_dat']
t0 = data['t_dat']

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

# %%
fig1 = plt.figure(figsize = (10, 7))
ax1 = plt.axes(projection ="3d")
 
# Creating plot
ax1.scatter3D(z_0, x_0, y_0, color = "blue")
plt.title("simple 3D scatter plot - inital position")
# rotate the axes and update
#ax.view_init(120,-90)
plt.savefig("3D-Plot-initial.png")

# %%
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(z_f, x_f, y_f, color = "green")
plt.title("simple 3D scatter plot - final position")
# rotate the axes and update
#ax.view_init(120,-90)
plt.savefig("3D-Plot-final.png")
